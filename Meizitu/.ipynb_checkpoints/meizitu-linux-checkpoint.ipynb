# %% [markdown]
# # Mysql 连接对象

# %%
import pymysql
import traceback

class DBHelper:
    def __init__(self):
        # 链接数据库
        try:
            # charset 默认是 latin1, 查询到中文会是？？
            # charset='utf8mb4' 避免有表情时插入错误
            self.__db = pymysql.connect(
                host='127.0.0.1',
                user='root',
                password='',
                database='test',
                charset='utf8mb4')
            self.__cur = self.__db.cursor()
        except pymysql.Error as e:
            print('链接数据库失败：', e.args[0], e.args[1])

    def insert(self, table, myDict):
        # 答案中存在表情会出错
        # 答案中存在双引号会出错，sql语句会发生歧义
        # 插入一条数据
        try:
            cols = ','.join(myDict.keys())
            values = ','.join(
                map(lambda x: '"' + str(x) + '"', myDict.values()))
            sql = 'INSERT INTO %s (%s) VALUES (%s)' % (table, cols, values)
            result = self.__cur.execute(sql)
            self.__db.commit()
        except pymysql.Error as e:
            print('插入失败：', e.args[0], e.args[1])
            # 发生错误时回滚
            # DML 语句，执行完之后，处理的数据，都会放在回滚段中（除了 SELECT 语句），
            # 等待用户进行提交（COMMIT）或者回滚 （ROLLBACK），当用户执行 COMMIT / ROLLBACK后，
            # 放在回滚段中的数据就会被删除。
            self.__db.rollback()

    def query(self, sql):
        try:
            self.__cur.execute(sql)
            result = self.__cur.fetchall()
            self.__db.commit()
            if result:
                return result
            else:
                return None
            
        except  pymysql.Error as e:
            print("数据库-查询异常", traceback.print_exc())
            
    def check_exist(self, table, record):
        try:
            sql = 'SELECT COUNT(*) FROM %s WHERE url= %s' % (table, record)
            result = self.__cur.execute(sql)
            if result > 0:
                return True
            else:
                return False
        except pymysql.Error as e:
            print('查询失败！', traceback.print_exc())
            return False
            
            
    def close(self ):
        self.__cur.close()
        self.__db.close()

# %% [markdown]
# # 爬取每个tag的首页地址

# %%
import requests
from bs4 import BeautifulSoup

def getAllTagsFirstLink():
    tag_list = []
    html = requests.get('http://www.meizitu.com')
    html.encoding = 'gbk'
    bsoup = BeautifulSoup(html.text.strip().replace('<!--   ','').replace('-->',''), "html.parser")
    tags = bsoup.find('div',{'class': 'tags'}).findAll('a')
    dbhelper = DBHelper()
    for a in tags:
        myDict = {
            'title': a.attrs['title'],
            'url':a.attrs['href']
        }
        tag_list.append(myDict)
        #print(a.attrs['title'],a.attrs['href'])
        dbhelper.insert('t_meizitu_tags_url',myDict)
    dbhelper.close()
    return tag_list
getAllTagsFirstLink()
# Out:
# 插入失败： 1406 Data too long for column 'url' at row 1
# [{'title': '颜值控', 'url': 'https://www.meizitu.com/a/pure.html'},
#  {'title': '萌妹', 'url': 'https://www.meizitu.com/a/cute.html'},
#  {'title': '性感', 'url': 'https://www.meizitu.com/a/sexy.html'},
#  {'title': '福利', 'url': 'https://www.meizitu.com/a/fuli.html'},
#  {'title': '长腿美臀', 'url': 'https://www.meizitu.com/a/legs.html'},
#  {'title': '日系妹纸', 'url': 'https://www.meizitu.com/a/rixi.html'},
#  {'title': '治愈系', 'url': 'https://www.meizitu.com/a/qingchun.html'},
#  {'title': '运动girl', 'url': 'https://www.meizitu.com/a/yundong.html'},
#  {'title': '清纯', 'url': 'https://www.meizitu.com/a/qingchun.html'},
#  {'title': '私房', 'url': 'https://www.meizitu.com/a/sifang.html'},
#  {'title': '模特', 'url': 'https://www.meizitu.com/tag/mote_6_1.html'},
#  {'title': '可爱', 'url': 'https://www.meizitu.com/tag/keai_64_1.html'},
#  {'title': '比基尼', 'url': 'https://www.meizitu.com/a/bijini.html'},
#  {'title': '气质', 'url': 'https://www.meizitu.com/tag/qizhi_53_1.html'},
#  {'title': '半裸', 'url': 'https://www.meizitu.com/tag/banluo_5_1.html'},
#  {'title': '女神', 'url': 'https://www.meizitu.com/tag/nvshen_460_1.html'},
#  {'title': '全裸', 'url': 'https://www.meizitu.com/tag/quanluo_4_1.html'},
#  {'title': '美臀', 'url': 'https://www.meizitu.com/tag/meitun_42_1.html'},
#  {'title': '成熟', 'url': 'https://www.meizitu.com/tag/chengshu_487_1.html'},
#  {'title': '性感', 'url': 'http://www.meizitu.com/a/xinggan.html'},
#  {'title': '浴室', 'url': 'http://www.meizitu.com/a/xinggan.html'},
#  {'title': '私房', 'url': 'http://www.meizitu.com/a/sifang.html'},
#  {'title': '美腿', 'url': 'http://www.meizitu.com/a/sifang.html'},
#  {'title': '清纯', 'url': 'http://www.meizitu.com/a/qingchun.html'},
#  {'title': '甜美', 'url': 'http://www.meizitu.com/a/qingchun.html'},
#  {'title': '治愈系', 'url': 'http://www.meizitu.com/a/qingchun.html'},
#  {'title': '萌妹子', 'url': 'http://www.meizitu.com/a/meizi.html'},
#  {'title': '小清新', 'url': 'http://www.meizitu.com/a/xiaoqingxin.htm'},
#  {'title': '女神', 'url': 'http://www.meizitu.com/a/nvshen.html'},
#  {'title': '气质美女', 'url': 'http://www.meizitu.com/a/qizhi.html'},
#  {'title': '嫩模', 'url': 'http://www.meizitu.com/a/mote.html'},
#  {'title': '车模', 'url': 'http://www.meizitu.com/a/mote.html'},
#  {'title': '比基尼', 'url': 'http://www.meizitu.com/a/bijini.html'},
#  {'title': '足球宝贝', 'url': 'http://www.meizitu.com/a/baobei.html'},
#  {'title': '萝莉', 'url': 'http://www.meizitu.com/a/luoli.html'},
#  {'title': '90后', 'url': 'http://www.meizitu.com/a/wangluo.html'},
#  {'title': '日韩美女', 'url': 'http://www.meizitu.com/a/rihan.html'},
#  {'title': '欧美美女', 'url': 'http://www.meizitu.com/a/oumei.html'}]

# %% [markdown]
# # 获取当前tag的所有html地址

# %%
import requests
from bs4 import BeautifulSoup
def get_tag_all_html_link(url):
    tagAllHtml = []
    tagAllHtml.append(url)
    html = requests.get(url)
    html.encoding='gbk'
    bsoup = BeautifulSoup(html.text,'html.parser').find('div',{'class','navigation'}).findAll('a')[:-2]
    if bsoup:
        for a in bsoup:
            if url.startswith('http://www.meizitu.com/a/'):
                tagAllHtml.append('http://www.meizitu.com/a/' + a.attrs['href'])
            else:
                tagAllHtml.append('http://www.meizitu.com' + a.attrs['href'])
    else:
        print('没有下一页！')
    return tagAllHtml
        
get_tag_all_html_link('http://www.meizitu.com/a/pure.html')
# Out:
# ['http://www.meizitu.com/a/pure.html',
#  'http://www.meizitu.com/a/pure_2.html',
#  'http://www.meizitu.com/a/pure_3.html',
#  'http://www.meizitu.com/a/pure_4.html',
#  'http://www.meizitu.com/a/pure_5.html',
#  'http://www.meizitu.com/a/pure_6.html',
#  'http://www.meizitu.com/a/pure_7.html',
#  'http://www.meizitu.com/a/pure_8.html',
#  'http://www.meizitu.com/a/pure_9.html',
#  'http://www.meizitu.com/a/pure_10.html',
#  'http://www.meizitu.com/a/pure_11.html',
#  'http://www.meizitu.com/a/pure_12.html',
#  'http://www.meizitu.com/a/pure_13.html',
#  'http://www.meizitu.com/a/pure_14.html',
#  'http://www.meizitu.com/a/pure_15.html']

# %% [markdown]
# # 模拟header

# %%
import random
UserAgent_List = [
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
    "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
    "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"]

def constructHeaders():
    headers = {
    'User-Agent': random.choice(UserAgent_List),
    'Accept': "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    'Accept-Encoding': 'gzip',
    }
    return headers
constructHeaders()
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3',
#  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
#  'Accept-Encoding': 'gzip'}

# %% [markdown]
# # 爬取代理ip存入数据库中

# %%
import requests
import re

url_proxy = 'http://www.xicidaili.com/nt/'
num = 2 #爬取页数，前两页
def ip_test(ip, headers, url_for_test='https://www.baidu.com', set_timeout=10):
    try:
        rp = requests.get(url_for_test, headers=headers, proxies={'http': ip[0] + ':' + ip[1]}, timeout = set_timeout)
        if rp.status_code == 200:
            return True
        else:
            return False
        
    except BaseException as e:
        return False
    
    
def sraw_ip(url_proxy, num,headers, url_for_test='https://www.baidu.com'):    
    ip_list = []
    dbhelper = DBHelper()
    for num_page in range (1, num +1):
        url_proxy = url_proxy + str(num_page)
        resp = requests.get(url_proxy, headers=headers, timeout = 10)
        resp.encoding = 'utf-8'
        htmlContent = resp.text
        
        pattern = re.compile('<td class="country">.*?alt="Cn" />.*?</td>.*?<td>(.*?)</td>.*?<td>(.*?)</td>',re.S)
        iterms = re.findall(pattern, htmlContent)
        for ip in iterms:
            if ip_test(ip, headers, url_for_test):
                print('测试通过，IP地址为' + str(ip[0]) + ':' + str(ip[1]))
                ip_list.append(ip[0] + ':' + ip[1])
                myDict = {'ip':ip[0] + ':' + ip[1]}
                dbhelper.insert('t_meizitu_proxy_ip', myDict)
            else:
                print('测试失败！')
    dbhelper.close()
    return ip_list

headers = constructHeaders()
sraw_ip(url_proxy, num, headers)
# Out:
# 测试通过，IP地址为122.228.19.8:3389
# 测试通过，IP地址为115.171.85.114:9000
# 测试通过，IP地址为222.249.238.138:8080
# 测试通过，IP地址为211.147.226.4:8118
# 测试通过，IP地址为171.221.116.156:8118
# 测试通过，IP地址为221.226.94.218:110
# 测试通过，IP地址为218.2.226.42:80
# 测试通过，IP地址为163.125.16.80:8888
# 测试通过，IP地址为163.125.72.40:9797
# 测试通过，IP地址为60.216.20.211:8001
# 测试通过，IP地址为61.133.87.228:55443
# 测试通过，IP地址为14.20.235.28:9797
# 测试通过，IP地址为223.245.47.116:65309
# 测试通过，IP地址为60.167.22.233:8118
# 测试通过，IP地址为116.252.39.176:53281
# 测试通过，IP地址为163.125.16.86:8888
# 测试通过，IP地址为116.196.87.86:20183
# 测试通过，IP地址为218.75.158.153:3128
# 测试通过，IP地址为116.196.85.150:3128
# 测试通过，IP地址为122.228.19.10:3389
# 测试通过，IP地址为122.200.90.12:47873
# 测试通过，IP地址为163.125.16.82:8888
# 测试通过，IP地址为122.228.19.90:3389
# 测试通过，IP地址为14.20.235.82:9797
# 测试通过，IP地址为59.38.62.183:9797
# 测试通过，IP地址为218.27.136.169:8085
# 测试通过，IP地址为112.250.107.37:53281
# 测试通过，IP地址为60.167.22.133:8118
# 测试通过，IP地址为60.191.11.237:3128
# 测试通过，IP地址为58.220.95.79:10000
# 测试通过，IP地址为58.220.95.78:9401
# 测试通过，IP地址为221.214.179.100:9090
# 测试通过，IP地址为125.123.21.11:9000
# 测试通过，IP地址为14.115.104.95:808
# 测试通过，IP地址为58.32.192.53:80
# 测试通过，IP地址为218.93.119.163:9002
# 测试通过，IP地址为125.46.0.62:53281
# 测试通过，IP地址为113.120.32.24:1081
# 测试通过，IP地址为118.114.166.99:8118
# 测试通过，IP地址为117.65.90.134:65309
# 测试通过，IP地址为183.129.207.87:12844
# 测试通过，IP地址为163.125.16.90:9999
# 测试通过，IP地址为113.59.99.138:8910
# 测试通过，IP地址为122.228.19.9:3389
# 测试通过，IP地址为118.25.13.185:8118
# 测试通过，IP地址为163.125.16.84:8888
# 测试通过，IP地址为59.38.60.185:9797
# 测试通过，IP地址为183.11.235.48:9292
# 测试通过，IP地址为60.191.11.229:3128
# 测试通过，IP地址为122.228.19.7:3389
# 测试通过，IP地址为113.65.163.199:9797
# 测试通过，IP地址为222.223.182.66:8000
# 测试通过，IP地址为125.123.65.60:9000
# 测试通过，IP地址为218.22.7.62:53281
# 测试通过，IP地址为163.125.254.137:9797
# 测试通过，IP地址为163.125.254.132:9797
# 测试通过，IP地址为163.125.253.22:9797
# 测试通过，IP地址为117.41.0.34:8080
# 测试通过，IP地址为183.63.188.250:8808
# 测试通过，IP地址为122.200.90.14:47873
# 测试通过，IP地址为221.229.252.98:8080
# 测试通过，IP地址为163.125.254.136:9797
# 测试通过，IP地址为61.145.182.27:53281
# 测试通过，IP地址为114.101.42.84:65309
# 测试通过，IP地址为61.153.251.150:22222
# 测试通过，IP地址为121.69.10.62:8080
# 测试通过，IP地址为115.196.93.78:8118
# 测试通过，IP地址为117.88.176.74:8118
# 测试通过，IP地址为60.191.11.246:3128
# 测试通过，IP地址为121.232.233.157:8118
# 测试通过，IP地址为110.73.5.87:9999
# 测试通过，IP地址为218.66.253.146:8800
# 测试通过，IP地址为112.64.233.130:9991
# 测试通过，IP地址为114.101.42.154:65309
# 测试通过，IP地址为123.113.248.44:8118
# 测试通过，IP地址为163.125.18.161:8888
# 测试通过，IP地址为163.125.18.173:8888
# 测试通过，IP地址为163.125.75.23:9000
# 测试通过，IP地址为36.6.88.148:65309
# 测试通过，IP地址为61.164.39.67:53281
# 测试通过，IP地址为114.249.114.117:9000
# 测试通过，IP地址为113.78.255.230:9000
# 测试通过，IP地址为60.205.132.71:80
# 测试通过，IP地址为114.220.182.166:8118
# 测试通过，IP地址为119.129.239.112:3128
# 测试通过，IP地址为121.13.252.60:41564
# 测试通过，IP地址为119.57.108.73:53281
# 测试通过，IP地址为163.125.18.168:8888
# 测试通过，IP地址为114.220.72.250:53281
# 测试通过，IP地址为42.228.3.158:8080
# 测试通过，IP地址为122.228.19.86:3389
# 测试通过，IP地址为122.224.65.201:3128
# 测试通过，IP地址为223.199.186.173:808
# 测试通过，IP地址为113.119.38.80:3128
# 测试通过，IP地址为119.130.106.54:3128
# 测试通过，IP地址为113.65.21.245:9797
# 测试通过，IP地址为115.239.24.243:9000
# 测试通过，IP地址为115.221.70.141:8118
# 测试通过，IP地址为113.251.171.58:8123
# 测试通过，IP地址为183.129.207.81:10800
# 测试通过，IP地址为125.62.27.53:3128
# 测试通过，IP地址为1.83.125.48:1080
# 测试通过，IP地址为171.37.78.125:9797
# 测试通过，IP地址为123.115.15.181:8118
# 测试通过，IP地址为182.108.44.108:3128
# 测试通过，IP地址为219.131.241.207:9797
# 测试通过，IP地址为119.123.178.197:9000
# 测试通过，IP地址为114.249.116.59:9000
# 测试通过，IP地址为114.249.117.253:9000
# 测试通过，IP地址为119.123.245.122:9000
# 测试通过，IP地址为111.194.118.67:9797
# 测试通过，IP地址为125.123.18.199:9000
# 测试通过，IP地址为113.78.254.107:9000
# 测试通过，IP地址为119.39.68.201:808
# 测试通过，IP地址为119.131.88.170:9797
# 测试通过，IP地址为112.95.191.136:9000
# 测试通过，IP地址为117.82.170.243:8118
# 测试通过，IP地址为119.123.247.83:9000
# 测试通过，IP地址为112.95.190.126:9999
# 测试通过，IP地址为14.115.106.16:808
# 测试通过，IP地址为163.125.71.222:8888
# 测试通过，IP地址为125.123.123.241:9000
# 测试通过，IP地址为180.76.149.31:8118
# 测试通过，IP地址为115.200.251.158:8118
# 测试通过，IP地址为119.130.107.252:3128
# 测试通过，IP地址为125.123.140.113:9000
# 测试通过，IP地址为27.46.20.67:8888
# 测试通过，IP地址为117.65.34.204:45619
# 测试通过，IP地址为219.131.242.165:3128
# 测试通过，IP地址为111.231.140.109:8888
# 测试通过，IP地址为182.92.105.136:3128
# 测试通过，IP地址为182.92.163.194:8118
# 测试通过，IP地址为14.155.112.156:9000
# 测试通过，IP地址为58.244.59.185:8080
# 测试通过，IP地址为125.123.45.45:9000
# 测试通过，IP地址为111.231.92.21:8888
# 测试通过，IP地址为119.131.88.43:9797
# 测试通过，IP地址为111.231.93.66:8888
# 测试通过，IP地址为163.125.69.126:8888
# 测试通过，IP地址为125.123.65.232:9000
# 测试通过，IP地址为49.72.20.183:9999
# 测试通过，IP地址为123.117.36.226:9000
# 测试通过，IP地址为14.115.106.209:808
# 测试通过，IP地址为114.249.116.203:9000
# 测试通过，IP地址为125.123.127.73:9000
# 测试通过，IP地址为122.141.74.186:8080
# 测试通过，IP地址为119.123.177.100:9000
# 测试通过，IP地址为1.195.57.3:9797
# 测试通过，IP地址为111.231.94.44:8888
# 测试通过，IP地址为111.231.90.122:8888
# 测试通过，IP地址为121.225.152.129:8118
# 测试通过，IP地址为112.95.20.24:8888
# 测试通过，IP地址为119.39.68.29:808
# 测试通过，IP地址为223.243.255.170:65309
# 测试通过，IP地址为114.139.32.251:8118
# 测试通过，IP地址为171.36.210.147:9797
# 测试通过，IP地址为27.46.22.5:8888
# 测试通过，IP地址为61.186.172.12:8118
# 测试通过，IP地址为113.116.244.99:9797
# 测试通过，IP地址为116.30.120.13:9000
# 测试通过，IP地址为183.129.207.92:11056
# 测试通过，IP地址为125.123.19.156:9000
# 测试通过，IP地址为222.132.41.192:9999
# 测试通过，IP地址为123.13.247.98:9999
# 测试通过，IP地址为14.115.105.51:808
# 测试通过，IP地址为182.61.162.160:3128
# 测试通过，IP地址为113.78.254.183:9999
# 测试通过，IP地址为59.38.61.1:9797
# 测试通过，IP地址为182.88.11.236:9797
# 测试通过，IP地址为171.36.43.217:9797
# 测试通过，IP地址为163.125.19.53:8888
# 测试通过，IP地址为183.30.204.214:9999
# 测试通过，IP地址为14.20.235.23:808
# 测试通过，IP地址为219.131.242.1:9797
# 测试通过，IP地址为163.125.75.41:9797
# 测试通过，IP地址为223.243.255.195:65309
# 测试通过，IP地址为58.215.75.194:8080
# 测试通过，IP地址为114.101.45.138:65309
# 测试通过，IP地址为112.95.205.94:8888
# 测试通过，IP地址为119.39.68.129:808
# 测试通过，IP地址为119.48.170.50:9999
# 测试通过，IP地址为111.177.79.8:9999
# 测试通过，IP地址为119.139.197.225:3128
# 测试通过，IP地址为14.115.104.210:808
# 测试通过，IP地址为113.116.244.212:9797
# 测试通过，IP地址为219.131.240.110:9797
# 测试通过，IP地址为171.36.164.194:9797
# 测试通过，IP地址为163.125.252.116:9797
# 测试通过，IP地址为163.125.150.79:9797
# 测试通过，IP地址为180.160.55.163:8118
# 测试通过，IP地址为114.239.0.17:808
# ['122.228.19.8:3389',
#  '115.171.85.114:9000',
#  '222.249.238.138:8080',
#  '211.147.226.4:8118',
#  '171.221.116.156:8118',
#  '221.226.94.218:110',
#  '218.2.226.42:80',
#  '163.125.16.80:8888',
#  '163.125.72.40:9797',
#  '60.216.20.211:8001',
#  '61.133.87.228:55443',
#  '14.20.235.28:9797',
#  '223.245.47.116:65309',
#  '60.167.22.233:8118',
#  '116.252.39.176:53281',
#  '163.125.16.86:8888',
#  '116.196.87.86:20183',
#  '218.75.158.153:3128',
#  '116.196.85.150:3128',
#  '112.95.190.126:9999',
#  '14.115.106.16:808',
#  '163.125.71.222:8888',
#  '125.123.123.241:9000',
#  '180.76.149.31:8118',
#  '115.200.251.158:8118',
#  '119.130.107.252:3128',
#  '125.123.140.113:9000',
#  '27.46.20.67:8888',
#  '117.65.34.204:45619',
#  '219.131.242.165:3128',
#  '111.231.140.109:8888',
#  '182.92.105.136:3128',
#  '182.92.163.194:8118',
#  '14.155.112.156:9000',
#  '58.244.59.185:8080',
#  '125.123.45.45:9000',
#  '111.231.92.21:8888',
#  '119.131.88.43:9797',
#  '111.231.93.66:8888',
#  '163.125.69.126:8888',
#  '125.123.65.232:9000',
#  '49.72.20.183:9999',
#  '123.117.36.226:9000',
#  '14.115.106.209:808',
#  '114.249.116.203:9000',
#  '125.123.127.73:9000',
#  '122.141.74.186:8080',
#  '119.123.177.100:9000',
#  '1.195.57.3:9797',
#  '111.231.94.44:8888',
#  '111.231.90.122:8888',
#  '121.225.152.129:8118',
#  '112.95.20.24:8888',
#  '119.39.68.29:808',
#  '223.243.255.170:65309',
#  '114.139.32.251:8118',
#  '171.36.210.147:9797',
#  '27.46.22.5:8888',
#  '61.186.172.12:8118',
#  '113.116.244.99:9797',
#  '116.30.120.13:9000',
#  '183.129.207.92:11056',
#  '125.123.19.156:9000',
#  '222.132.41.192:9999',
#  '123.13.247.98:9999',
#  '14.115.105.51:808',
#  '182.61.162.160:3128',
#  '113.78.254.183:9999',
#  '59.38.61.1:9797',
#  '182.88.11.236:9797',
#  '171.36.43.217:9797',
#  '163.125.19.53:8888',
#  '183.30.204.214:9999',
#  '14.20.235.23:808',
#  '219.131.242.1:9797',
#  '163.125.75.41:9797',
#  '223.243.255.195:65309',
#  '58.215.75.194:8080',
#  '114.101.45.138:65309',
#  '112.95.205.94:8888',
#  '119.39.68.129:808',
#  '119.48.170.50:9999',
#  '111.177.79.8:9999',
#  '119.139.197.225:3128',
#  '14.115.104.210:808',
#  '113.116.244.212:9797',
#  '219.131.240.110:9797',
#  '171.36.164.194:9797',
#  '163.125.252.116:9797',
#  '163.125.150.79:9797',
#  '180.160.55.163:8118',
#  '114.239.0.17:808']

# %% [markdown]
# # 获取每个tag的所有html地址并保存

# %%
def save_all_tags_html_links():
    dbhelper = DBHelper()
    html_links = []
    for tags in getAllTagsFirstLink():
        print(tags['url'])
        allinks = get_tag_all_html_link(tags['url'])
        for urlink in allinks:
            #print(tags['title'], urlink)
            myDict={'tag':tags['title'], 'html_url':urlink}
            dbhelper.insert('t_meizitu_tag_html_urls',myDict)
    dbhelper.close()
save_all_tags_html_links()
# Out:
# https://www.meizitu.com/a/pure.html
# https://www.meizitu.com/a/cute.html
# https://www.meizitu.com/a/sexy.html
# https://www.meizitu.com/a/fuli.html
# https://www.meizitu.com/a/legs.html
# https://www.meizitu.com/a/rixi.html
# https://www.meizitu.com/a/qingchun.html
# https://www.meizitu.com/a/yundong.html
# https://www.meizitu.com/a/qingchun.html
# https://www.meizitu.com/a/sifang.html
# https://www.meizitu.com/tag/mote_6_1.html
# https://www.meizitu.com/tag/keai_64_1.html
# https://www.meizitu.com/a/bijini.html
# https://www.meizitu.com/tag/qizhi_53_1.html
# https://www.meizitu.com/tag/banluo_5_1.html
# https://www.meizitu.com/tag/nvshen_460_1.html
# https://www.meizitu.com/tag/quanluo_4_1.html
# https://www.meizitu.com/tag/meitun_42_1.html
# https://www.meizitu.com/tag/chengshu_487_1.html
# http://www.meizitu.com/a/xinggan.html
# http://www.meizitu.com/a/xinggan.html
# http://www.meizitu.com/a/sifang.html
# http://www.meizitu.com/a/sifang.html
# http://www.meizitu.com/a/qingchun.html
# http://www.meizitu.com/a/qingchun.html
# http://www.meizitu.com/a/qingchun.html
# http://www.meizitu.com/a/meizi.html
# http://www.meizitu.com/a/xiaoqingxin.htm
# http://www.meizitu.com/a/nvshen.html
# http://www.meizitu.com/a/qizhi.html
# http://www.meizitu.com/a/mote.html
# http://www.meizitu.com/a/mote.html
# http://www.meizitu.com/a/bijini.html
# http://www.meizitu.com/a/baobei.html
# http://www.meizitu.com/a/luoli.html
# http://www.meizitu.com/a/wangluo.html
# http://www.meizitu.com/a/rihan.html
# http://www.meizitu.com/a/oumei.html
# 没有下一页！

# %% [markdown]
# # 获取当前page的相册链接列表

# %%
import requests
from bs4 import BeautifulSoup
def get_current_page_albums(page):
    current_page_albums = []
    rep = requests.get(page)
    rep.encoding = 'gb2312'
    bsoup = BeautifulSoup(rep.text, 'html.parser')
    album_list = bsoup.find('ul', {'class', 'wp-list clearfix'}).findAll('li', {'class', 'wp-item'})
    for album in album_list:
        album_link = album.find('h3',{'class', 'tit'}).find('a').attrs['href']
        current_page_albums.append(album_link)
    return current_page_albums

# %% [markdown]
# # 获取当前相册的图片链接及标题

# %%
import requests
import time
import traceback
from bs4 import BeautifulSoup

def get_current_album_title_imgs(current_page_albums_links, tag_path):
    try:
        for link in current_page_albums_links:
            rep = requests.get(link)
            rep.encoding = 'gb2312'
            bsoup = BeautifulSoup(rep.text, 'html.parser')
            imgs = bsoup.find('div', {'class', 'postContent'}).find('p').findAll('img')
            album_title = bsoup.find('div',{'class', 'metaRight'}).find('a').text
            download_album(tag_path, imgs, album_title)
            time.sleep(5)
    except BaseException as e:
        print('获取每个相册图片 & 标题异常！', traceback.print_exc())
        
current_page_albums_links = ['http://www.meizitu.com/a/3668.html', 'http://www.meizitu.com/a/5527.html']
        
get_current_album_title_imgs(current_page_albums_links, '/Users/biguodong/Documents/mzitu')
# Out:
# 陈怡曼浴缸美妙肉体诱惑01.jpg download successfully!
# 陈怡曼浴缸美妙肉体诱惑02.jpg download successfully!
# 陈怡曼浴缸美妙肉体诱惑03.jpg download successfully!
# 陈怡曼浴缸美妙肉体诱惑04.jpg download successfully!
# 陈怡曼浴缸美妙肉体诱惑05.jpg download successfully!
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/01.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b105950>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/02.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b1057d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/03.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b1057d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/04.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b105610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/05.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b105490>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/06.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b105550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/07.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b105250>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/08.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b1058d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/09.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b1054d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# 图片下载失败--！ HTTPConnectionPool(host='mm.chinasareview.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017a/04/15/10.gif (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10b105110>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# # 创建相应的相册，并下载相册

# %%
import os
def download_album(tag_path, imgs, album_title):
    headers = constructHeaders()
    for img in imgs:
        album_title = format_text(album_title)
        img_src = img.attrs['src']
        title = format_text(img.attrs['alt']) + img_src.split('/')[-1]
        if title.startswith('妹子图微信'):
            continue
        else:
            try:
                if not os.path.exists(os.path.join(tag_path, album_title)):
                    os.makedirs(os.path.join(tag_path, album_title))
                os.chdir(tag_path + "/" + album_title)
                exists = os.path.exists(album_title)
                if not exists:               
                    try:
                        img_html = requests.get(img_src, headers=headers, stream=True, timeout=30, verify=True)
                        with open(title + '.jpg', 'wb') as f:                        
                            f.write(img_html.content)
                            f.close()
                            print(title + " download successfully!")
                    except BaseException as e:
                        print('图片下载失败--！', e)
            except BaseException as e2:
                print('相册文件构建失败！', str(e2))
                continue

# %% [markdown]
# # 文本格式化

# %%
#对名字进行处理，如果包含下属字符，则直接剔除该字符
def format_text(text):
    text = text.strip()
    for i in ['\\', '/', ':', '*', '?', '"', '<', '>', '!', '|']:
        while i in text:
            text = text.replace(i, '')
    return text

# %%
import traceback
def test():
    try:
        sql = 'SELECT title,scrawl_flag from t_meizitu_tags_url where scrawl_flag !="1" ORDER BY title asc'
        dbhelper = DBHelper()
        result = dbhelper.query(sql)
        print(result)
    except BaseException as e:
         print(e, traceback.print_exc())
test()
# Out:
# (('半裸', '0'), ('可爱', '0'), ('女神', '0'), ('女神', '0'), ('嫩模', '0'), ('小清新', '0'), ('性感', '0'), ('性感', '0'), ('成熟', '0'), ('日系妹纸', '0'), ('日韩美女', '0'), ('模特', '0'), ('欧美美女', '0'), ('比基尼', '0'), ('比基尼', '0'), ('气质', '0'), ('气质美女', '0'), ('治愈系', '0'), ('治愈系', '0'), ('浴室', '0'), ('清纯', '0'), ('清纯', '0'), ('甜美', '0'), ('福利', '0'), ('私房', '0'), ('私房', '0'), ('美腿', '0'), ('美臀', '0'), ('萌妹', '0'), ('萌妹子', '0'), ('萝莉', '0'), ('足球宝贝', '0'), ('车模', '0'), ('运动girl', '0'), ('长腿美臀', '0'), ('颜值控', '0'))

# %% [markdown]
# # Main  根据tag创建本地文件夹下载图片

# %%
import os
def  create_tags_dir(base_url):
    dbhelper = DBHelper()
    sql = 'SELECT title from t_meizitu_tags_url where scrawl_flag != "1" ORDER BY title asc'
    result = dbhelper.query(sql)
    try:
        if result:
            #遍历数据库中的每个tag
            for tag in result:
                if not os.path.exists(os.path.join(base_url, tag[0])):
                    os.makedirs(os.path.join(base_url, tag[0]))
                os.chdir(base_url + '/' + tag[0])
                sql_tag = 'SELECT html_url FROM t_meizitu_tag_html_urls WHERE tag =' + "'" + tag[0] + "'" + ' ORDER BY html_url asc'
                result_tag = dbhelper.query(sql_tag)
                if not result_tag:
                    print("%s 下没有发现url！", tag)
                else:
                    #处理当前tag的 当前页面 里的相册
                    for page in result_tag:
                        #获得当前页面的 相册链接地址列表
                        current_page_albums_links = get_current_page_albums(page[0])
                        #获取单个相册中图片url 链接地址及 相册名称
                        get_current_album_title_imgs(current_page_albums_links, base_url + '/' + tag[0])                    
                        
                        
        else:
            print("查询异常！")
    except BaseException as e:
        print('操作异常：',e)
    finally:
        dbhelper.close()    
            
    
create_tags_dir('/home/jelly/Meizitu')
# Out:
# 年轻嫩模海岛任意放飞自己，第1张01.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第2张02.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第3张03.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第4张04.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第5张05.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第6张06.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第7张07.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第8张08.jpg download successfully!
# 年轻嫩模海岛任意放飞自己，第9张09.jpg download successfully!
# 香车美女，最完美的黄金搭档，第1张01.jpg download successfully!
# 香车美女，最完美的黄金搭档，第2张02.jpg download successfully!
# 香车美女，最完美的黄金搭档，第3张03.jpg download successfully!
# 香车美女，最完美的黄金搭档，第4张04.jpg download successfully!
# 香车美女，最完美的黄金搭档，第5张05.jpg download successfully!
# 香车美女，最完美的黄金搭档，第6张06.jpg download successfully!
# 香车美女，最完美的黄金搭档，第6张07.jpg download successfully!
# 香车美女，最完美的黄金搭档，第6张08.jpg download successfully!
# 香车美女，最完美的黄金搭档，第7张09.jpg download successfully!
# 王�t晨写真，第1张01.jpg download successfully!
